# %% [markdown]
# PROJETO - WORDCLOUD MAMA'S GUNS
#
# Bibliotecas a serem utilizadas:
# - RE
# - Requests
# - WordCloud
# - Matplotlib
# - Numpy
# - PIL

# %%
import re 
import requests
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import numpy as np
from PIL import Image

# %%
# Abrir o txt como uma variavel
with open ('./MamasGunLyrics.txt', 'r') as lyric:
    words = lyric.read()

print("Quantidade de palavras: ", len(words))
# Out:
# Quantidade de palavras:  19845

# %%
# organizar numa lista de palavras
tokens = words.split()

# conversão em minusculo
for i in range(len(tokens)):
    tokens[i] = tokens[i].lower().strip()

print("Algumas palavras em lista para confirmar: ",tokens[:20])
# Out:
# Algumas palavras em lista para confirmar:  ["here's", 'my', 'philosophy', "livin'", 'in', 'a', 'penitentiary', 'brothers', 'all', 'on', 'the', 'corner', "tryin'", 'to', 'make', 'believe', 'turn', 'around', "ain't", 'got']

# %%
# Como o WordCloud não consegue utilizar as palavras em lista, é preciso adicionar tudo em uma grande string.
wordsTogether = " ".join(tokens)

print("Algumas palavras em lista para confirmar: ",wordsTogether[0:5000])
# Out:
# Algumas palavras em lista para confirmar:  here's my philosophy livin' in a penitentiary brothers all on the corner tryin' to make believe turn around ain't got no pot to pee make me mad when i see ya sad can't stand to see ya hustle doin' bad but you can't win when your will is weak when you're knocked on the ground evil, don't you test me evil, you won't win oh why world why world do want me to be so mad yeah so mad yeah oh why world why world do you want me to be so mad yeah so mad yeah i'm tellin' you the truth i hope i'm not being too cruel since you ain't playing by the rules i'm 'bout to kick you off your stool evil, don't you test me evil, you won't win oh why world why world do want me to be so mad yeah so mad yeah oh why world why world do you want me to be so mad yeah so mad yeah i am a warrior princess i have come from the other sun gather all of your members unite them as one move together in harmony build a bridge now destroy a bridge eliminate your weakness conquer evil, the demon and live forever together oh why can't we get along and take all the funky tones and make up a funky song that be bangin' on and on make me mad when i see ya sad with the same look ya momma had but ya can't win when your will is weak but ya get out ya seat oh why why why world do you want me to be so mad so mad yeah why in the world why world do you want me to be so mad yeah so mad yeah why in the world why world do you want me to be so mad yeah so mad yeah why in the world why world do you want me to be so mad yeah so mad yeah why make me, make me, make me, make me, make me so mad why yeah, why yeah, why yeah why yeah.. ooh, hey i'm trying to decide which way to go think i made a wrong turn back there somewhere ooh, hey i'm trying to decide which way to go think i made a wrong turn back there somewhere didn't cha know, didn't cha know tried to move but i lost my way didn't cha know, didn't cha know stopped to watch my emotions sway didn't cha know, didn't cha know knew the toll but i would not pay didn't cha know, didn't cha know 'cause you never know where the cards may lay time to save the world where in the world is all the time? so many things i still don't know so many times i've changed my mind guess i was born to make mistakes but i ain't scared to take the weight so when i stumble off the path i know my heart will guide me back ooh, hey i'm trying to decide which way to go think i made a wrong turn back there somewhere ooh, hey, ooh i'm trying to decide which way to go i think i made a wrong turn back there somewhere didn't cha know, didn't cha know tried to run but i lost my way didn't cha know, didn't cha know stopped to watch my emotions sway didn't cha know, didn't cha know knew the toll but i would not pay didn't cha know, didn't cha know i said ya never know how the cards may lay love is life, and life is free take a ride of life with me free your mind and find your way there will be a brighter day love is life, and life is free take a ride of life with me free your mind and find your way there will be a brighter day love is life, and life is free take a ride of life with me free your mind and find your way there will be a brighter day i was standing downtown, downtown staring at the puddles on the ground tryin' to figure out a way up out of this town and i know yeah, i'm not the only one so many people out there chase the sun if you're looking for a free ride you better run child or you sure won't get too far, oh you'd better dance a dance to make the rain come down if you want to be a star, oh, my life my life (brother you know) sure ain't been too easy my life (sister you know) the life i wanna live my life (mama you know) you're gonna go through changes my life (i'm tellin' you no) no turnin' back every now and then i wanna throw my hands up in the sky cause one day i know i'll be flyin' high and i know yeah i got to get down on my knees and pray cause in heart i know i'll see that day when my freedom comes along i'm ...

# %%
# Configuração do WordCloud. StopWord e configurações graficas.
stopwords_custom = STOPWORDS.union({'is', 'is', 'said', 'how', 'but', 'my', 'make', 'move', 'said', 'nigga', 'will', 'see', 'oh', 'say', 'di', "ain't", 'da', 'cause', 'know'})

# Função para converter código hexadecimal para RGB
def hex_to_rgb(hex_code):
    hex_code = hex_code.lstrip('#')
    rgb = tuple(int(hex_code[i:i+2], 16) for i in (0, 2, 4))
    return rgb

background_color = hex_to_rgb('#340A14')

###
# Criando um gradiente de cores personalizado
colors = ["#A93830", "#F28E37", "#CD622B", '#88733C']
cmap = LinearSegmentedColormap.from_list("mycmap", colors)


wordcloud = WordCloud(background_color=background_color,
            stopwords = stopwords_custom,
            contour_width = 1,
            width=1600, height=800,
            colormap=cmap,
            contour_color = 'blue',
            font_path='./impact.ttf',
            random_state=50).generate(wordsTogether)

# Mostrando a imagem do wordcloud
plt.figure(figsize = (20, 10), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')

# Remover os eixos do grafico
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %%
# Para realizar a contagem de quantidade das palavras, a gente pode utilizar a biblioteca Colletions, e sua função Counter

from collections import Counter

erykahwords_count = Counter(tokens)

erykahwords_count.most_common()
# Out:
# [('i', 155),
#  ('you', 136),
#  ('the', 83),
#  ('to', 83),
#  ('in', 81),
#  ('and', 81),
#  ('my', 76),
#  ('love', 75),
#  ('with', 71),
#  ('me', 70),
#  ('your', 70),
#  ('it', 63),
#  ("don't", 59),
#  ('a', 58),
#  ("i'm", 56),
#  ('so', 45),
#  ('but', 43),
#  ('be', 36),
#  ('no', 35),
#  ('want', 35),
#  ('let', 35),
#  ("can't", 32),
#  ('know', 31),
#  ('on', 30),
#  ("ain't", 30),
#  ('go,', 30),
#  ('why', 29),
#  ('world', 29),
#  ('yeah', 28),
#  ('too', 28),
#  ('what', 28),
#  ('do', 27),
#  ('life', 24),
#  ('oh', 23),
#  ('that', 23),
#  ('he', 23),
#  ('go', 22),
#  ('all', 20),
#  ('mad', 20),
#  ('when', 20),
#  ("it's", 20),
#  ('alright', 20),
#  ('make', 19),
#  ('is', 18),
#  ('one', 18),
#  ('ooh,', 18),
#  ('you,', 18),
#  ('ya', 17),
#  ('way', 17),
#  ('cha', 17),
#  ('if', 17),
#  ("didn't", 16),
#  ('him', 16),
#  ('baby', 16),
#  ('of', 15),
#  ('where', 15),
#  ('said', 15),
#  ('cause', 15),
#  ('need', 14),
#  ("you'll", 14),
#  ('got', 13),
#  ('we', 13),
#  ('up', 13),
#  ('oh,', 13),
#  ('they', 13),
#  ('see', 12),
#  ('back', 12),
#  ('wanna', 12),
#  ('bag', 12),
#  ('mind', 11),
#  ('ooh', 11),
#  ('this', 11),
#  ('good', 11),
#  ('badu', 11),
#  ("gon'", 11),
#  ('no,', 11),
#  ('telling', 11),
#  ('land', 11),
#  ('late', 11),
#  ('will', 10),
#  ('get', 10),
#  ('take', 10),
#  ('there', 10),
#  ('never', 10),
#  ('day', 10),
#  ('(let', 10),
#  ('go)', 10),
#  ("won't", 9),
#  ('not', 9),
#  ('made', 9),
#  ('know,', 9),
#  ('was', 9),
#  ('how', 9),
#  ('down', 9),
#  ('know)', 9),
#  ("(i'm", 9),
#  ('then', 9),
#  ('smile', 9),
#  ('nigga', 9),
#  ('day,', 9),
#  ("you're", 8),
#  ('come', 8),
#  ('out', 8),
#  ("'cause", 8),
#  ('run', 8),
#  ('been', 8),
#  ('say,', 8),
#  ('light', 8),
#  ("that's", 8),
#  ('done', 8),
#  ('neck', 8),
#  ('pack', 8),
#  ('about', 8),
#  ('them', 7),
#  ('me,', 7),
#  ('think', 7),
#  ('free', 7),
#  ('understand', 7),
#  ('him,', 7),
#  ('breathe', 7),
#  ('could', 7),
#  ('care', 7),
#  ('leave,', 7),
#  ('off', 6),
#  ('knew', 6),
#  ('people', 6),
#  ('for', 6),
#  ('gonna', 6),
#  ('like', 6),
#  ('words', 6),
#  ('you?', 6),
#  ("talkin'", 6),
#  ('shit', 6),
#  ('badu,', 6),
#  ('keep', 6),
#  ('his', 6),
#  ('feel', 6),
#  ('more', 6),
#  ('friend', 6),
#  ('say', 6),
#  ('lady', 6),
#  ('try', 6),
#  ('try,', 6),
#  ('you)', 6),
#  ('late,', 6),
#  ('turn', 5),
#  ('evil,', 5),
#  ('have', 5),
#  ('from', 5),
#  ('sun', 5),
#  ('live', 5),
#  ('same', 5),
#  ('hey', 5),
#  ('wrong', 5),
#  ('lost', 5),
#  ('time', 5),
#  ('many', 5),
#  ('changed', 5),
#  ('hey,', 5),
#  ('brighter', 5),
#  ('at', 5),
#  ('better', 5),
#  ('through', 5),
#  ('she', 5),
#  ('moon', 5),
#  ('remember', 5),
#  ('really', 5),
#  ('last', 5),
#  ('eyes', 5),
#  ('are', 5),
#  ('much', 5),
#  ('ever', 5),
#  ('orange', 5),
#  ('turned', 5),
#  ('me)', 5),
#  ('bags', 5),
#  ('lady?', 5),
#  ('man', 5),
#  ('win', 4),
#  ("tellin'", 4),
#  ('hope', 4),
#  ('yeah,', 4),
#  ('trying', 4),
#  ('decide', 4),
#  ('which', 4),
#  ('somewhere', 4),
#  ('still', 4),
#  ('heart', 4),
#  ('ride', 4),
#  ('find', 4),
#  ('sure', 4),
#  ("i'll", 4),
#  ('bring', 4),
#  ('just', 4),
#  ('might', 4),
#  ('cleva', 4),
#  ('green', 4),
#  ('lot', 4),
#  ("he's", 4),
#  ('ready', 4),
#  ('well', 4),
#  ('told', 4),
#  ('somebody', 4),
#  ('behind', 4),
#  ('kiss', 4),
#  ("name'n", 4),
#  ('after', 4),
#  ('an', 4),
#  ('than', 4),
#  ('(no', 4),
#  ('light,', 4),
#  ('"you', 4),
#  ('crowding', 4),
#  ('space"', 4),
#  ('(bet', 4),
#  ('better)', 4),
#  ("time's", 4),
#  ("wastin'", 4),
#  ('time,', 4),
#  ('young', 4),
#  ('drifting', 4),
#  ('living', 4),
#  ('nothing', 4),
#  ("tryin'", 3),
#  ('believe', 3),
#  ('sad', 3),
#  ('since', 3),
#  ('move', 3),
#  ('now', 3),
#  ('look', 3),
#  ('tried', 3),
#  ('may', 3),
#  ('life,', 3),
#  ('child', 3),
#  ('(brother', 3),
#  ('easy', 3),
#  ('(sister', 3),
#  ('(mama', 3),
#  ('changes', 3),
#  ('no)', 3),
#  ("turnin'", 3),
#  ('every', 3),
#  ('&', 3),
#  ('see,', 3),
#  ('always', 3),
#  ('give', 3),
#  ('water', 3),
#  ('gotta', 3),
#  ('grow', 3),
#  ("nothin'", 3),
#  ('erykah', 3),
#  ('whole', 3),
#  ('arrangement', 3),
#  ('money', 3),
#  ('walk', 3),
#  ('air', 3),
#  ('these', 3),
#  ('buildings', 3),
#  ('name', 3),
#  ('smiled', 3),
#  ('before', 3),
#  ('da', 3),
#  ('yo', 3),
#  ('(*scat*)', 3),
#  ('yes', 3),
#  ('hurt', 3),
#  ('so,', 3),
#  ('running', 3),
#  ('taking', 3),
#  ('change', 3),
#  ('vegetables', 3),
#  ('new', 3),
#  ('insecure', 3),
#  ('me?', 3),
#  ('philosophy', 2),
#  ("livin'", 2),
#  ('penitentiary', 2),
#  ('brothers', 2),
#  ('pot', 2),
#  ('stand', 2),
#  ('bad', 2),
#  ('weak', 2),
#  ('ground', 2),
#  ('test', 2),
#  ("'bout", 2),
#  ('am', 2),
#  ('together', 2),
#  ('bridge', 2),
#  ('along', 2),
#  ('funky', 2),
#  ('momma', 2),
#  ('stopped', 2),
#  ('watch', 2),
#  ('emotions', 2),
#  ('sway', 2),
#  ('toll', 2),
#  ('would', 2),
#  ('pay', 2),
#  ('cards', 2),
#  ('lay', 2),
#  ('things', 2),
#  ('times', 2),
#  ("i've", 2),
#  ('guess', 2),
#  ('standing', 2),
#  ('figure', 2),
#  ('dance', 2),
#  ('hands', 2),
#  ('sky', 2),
#  ('knees', 2),
#  ('nobody', 2),
#  ('who', 2),
#  ('fuck', 2),
#  ('long', 2),
#  ("what's", 2),
#  ('right', 2),
#  ('rolling', 2),
#  ('start', 2),
#  ('everybody', 2),
#  ('ask', 2),
#  ('well,', 2),
#  ("swimmin'", 2),
#  ('zip', 2),
#  ('dip', 2),
#  ('felt', 2),
#  ('first', 2),
#  ('though', 2),
#  ('did', 2),
#  ('god', 2),
#  ('low', 2),
#  ('clever', 2),
#  ('bust', 2),
#  ('rhyme', 2),
#  ("she's", 2),
#  ('know?', 2),
#  ('fly', 2),
#  ('booty', 2),
#  ('can', 2),
#  ('thinks', 2),
#  ('doing', 2),
#  ("would've", 2),
#  ('thing', 2),
#  ('door,', 2),
#  ('again', 2),
#  ('divine', 2),
#  ('water,', 2),
#  ('abuse', 2),
#  ('herbs', 2),
#  ('rare', 2),
#  ('dilapidated', 2),
#  ('mistated,', 2),
#  ('surely', 2),
#  ('conscious', 2),
#  ('it,', 2),
#  ('nights', 2),
#  ('alone', 2),
#  ('many,', 2),
#  ('bright', 2),
#  ('away', 2),
#  ('is,', 2),
#  ('says', 2),
#  ('overstand', 2),
#  ('mama', 2),
#  ('open', 2),
#  ('try)', 2),
#  ('were', 2),
#  ('mean', 2),
#  ('say)', 2),
#  ('(i', 2),
#  ('lady,', 2),
#  ('yes,', 2),
#  ('inside', 2),
#  ('better,', 2),
#  ('sack', 2),
#  ('ladies', 2),
#  ('baby,', 2),
#  ("we're", 2),
#  ('oh-so-strange', 2),
#  ('boy,', 2),
#  ('focus', 2),
#  ('demons', 2),
#  ('range', 2),
#  ('oh-so-fast', 2),
#  ('learn', 2),
#  ('eat', 2),
#  ('any', 2),
#  ('thought', 2),
#  ('silly', 2),
#  ('afraid,', 2),
#  ("here's", 1),
#  ('corner', 1),
#  ('around', 1),
#  ('pee', 1),
#  ('hustle', 1),
#  ("doin'", 1),
#  ('knocked', 1),
#  ('truth', 1),
#  ('being', 1),
#  ('cruel', 1),
#  ('playing', 1),
#  ('by', 1),
#  ('rules', 1),
#  ('kick', 1),
#  ('stool', 1),
#  ('warrior', 1),
#  ('princess', 1),
#  ('other', 1),
#  ('gather', 1),
#  ('members', 1),
#  ('unite', 1),
#  ('as', 1),
#  ('harmony', 1),
#  ('build', 1),
#  ('destroy', 1),
#  ('eliminate', 1),
#  ('weakness', 1),
#  ('conquer', 1),
#  ('demon', 1),
#  ('forever', 1),
#  ('tones', 1),
#  ('song', 1),
#  ("bangin'", 1),
#  ('had', 1),
#  ('seat', 1),
#  ('yeah..', 1),
#  ('save', 1),
#  ('time?', 1),
#  ('born', 1),
#  ('mistakes', 1),
#  ('scared', 1),
#  ('weight', 1),
#  ('stumble', 1),
#  ('path', 1),
#  ('guide', 1),
#  ('downtown,', 1),
#  ('downtown', 1),
#  ('staring', 1),
#  ('puddles', 1),
#  ('town', 1),
#  ('only', 1),
#  ('chase', 1),
#  ('looking', 1),
#  ('or', 1),
#  ('far,', 1),
#  ("you'd", 1),
#  ('rain', 1),
#  ('star,', 1),
#  ('throw', 1),
#  ("flyin'", 1),
#  ('high', 1),
#  ('pray', 1),
#  ('freedom', 1),
#  ('comes', 1),
#  ('far', 1),
#  ('kill', 1),
#  ('soul', 1),
#  ('are,', 1),
#  ('wake', 1),
#  ('wait', 1),
#  ('minute,', 1),
#  ('queen,', 1),
#  ('name?', 1),
#  ('gypsy', 1),
#  ("flippin'", 1),
#  ('game', 1),
#  ('brain', 1),
#  ('(huh)', 1),
#  ('ascension', 1),
#  ('maintained', 1),
#  ('burning', 1),
#  ('flame', 1),
#  ('supernova', 1),
#  ('star', 1),
#  ('dark', 1),
#  ('morning', 1),
#  ('pass', 1),
#  ('four', 1),
#  ('constellations', 1),
#  ('forming', 1),
#  ('cross', 1),
#  ('pisces', 1),
#  ('zika', 1),
#  ('deka', 1),
#  ('del', 1),
#  ('raising', 1),
#  ('hell', 1),
#  ('envy', 1),
#  ('women', 1),
#  ('rule', 1),
#  ('men', 1),
#  ('two', 1),
#  ('fish,', 1),
#  ('stream', 1),
#  ('dream', 1),
#  ('loves', 1),
#  ('tends', 1),
#  ('cling', 1),
#  ('incense', 1),
#  ('burns,', 1),
#  ('smoke', 1),
#  ('unfurls', 1),
#  ('analog', 1),
#  ('girl', 1),
#  ('digital', 1),
#  ('rasta', 1),
#  ('style', 1),
#  ('flower', 1),
#  ('dow,', 1),
#  ('dow', 1),
#  ('gold', 1),
#  ('tooth', 1),
#  ('split', 1),
#  ('vowels', 1),
#  ('bling', 1),
#  ('bloom', 1),
#  ('bling,', 1),
#  ('melanated', 1),
#  ('ta', 1),
#  ('birth', 1),
#  ('church', 1),
#  ('earth', 1),
#  ('what...', 1),
#  ('bridge!', 1),
#  ('went', 1),
#  ('washateria', 1),
#  ('started', 1),
#  ('period', 1),
#  ('school', 1),
#  ('learned', 1),
#  ('inferior', 1),
#  ('cereal', 1),
#  ('stereo', 1),
#  ('holla', 1),
#  ('hear', 1),
#  ('remembering', 1),
#  ('fear', 1),
#  ('wrap', 1),
#  ('head', 1),
#  ('material', 1),
#  ('(material)', 1),
#  ('math', 1),
#  ('cypher', 1),
#  ('keeps', 1),
#  ('moving', 1),
#  ('stone', 1),
#  ('props', 1),
#  ('jaborn', 1),
#  ('singers', 1),
#  ('sing', 1),
#  ('beats', 1),
#  ('us', 1),
#  ('have,', 1),
#  ("mo'", 1),
#  ('without', 1),
#  ('makeup', 1),
#  ('bra', 1),
#  ("ninny's", 1),
#  ('sag', 1),
#  ('hair', 1),
#  ('hung', 1),
#  ('shoulders', 1),
#  ('little', 1),
#  ('belly', 1),
#  ('days', 1),
#  ('dress', 1),
#  ('cost', 1),
#  ('seven', 1),
#  ('dollars', 1),
#  ('tell', 1),
#  ('also', 1),
#  ('didnâ€™t', 1),
#  ('bigger', 1),
#  ('pull', 1),
#  ('sugar', 1),
#  ('pita', 1),
#  ('sweeter', 1),
#  ('encyclopedia', 1),
#  ('deeper', 1),
#  ('junk', 1),
#  ('trunk', 1),
#  ('crunk', 1),
#  ('kisses', 1),
#  ('wetter', 1),
#  ('likes', 1),
#  ('mine', 1),
#  ('beans', 1),
#  ('rice', 1),
#  ('hot', 1),
#  ('ho-cakes', 1),
#  ('over', 1),
#  ('here', 1),
#  ('plate', 1),
#  ('phd,', 1),
#  ('magna', 1),
#  ('cum', 1),
#  ('laude', 1),
#  ('ged', 1),
#  ('knows', 1),
#  ("money's", 1),
#  ('funny', 1),
#  ('boy', 1),
#  ('pad', 1),
#  ('decked', 1),
#  ("fo'", 1),
#  ("sho'", 1),
#  ("nigga's", 1),
#  ('butterfly', 1),
#  ('tootsie', 1),
#  ('roll', 1),
#  ('straight', 1),
#  ('sprung', 1),
#  ('stroll', 1),
#  ('120', 1),
#  ('plus', 1),
#  ('degree', 1),
#  ('nine-to-five', 1),
#  ('six-to-ten', 1),
#  ('work', 1),
#  ('such', 1),
#  ('forgot', 1),
#  ('fine', 1),
#  ('do?', 1),
#  ('plan?', 1),
#  ('bulidings', 1),
#  ('surely,', 1),
#  ('surely...', 1),
#  ('reflecting', 1),
#  ('stood', 1),
#  ('night', 1),
#  ('saw', 1),
#  ('reflection', 1),
#  ('shine', 1),
#  ('reflect', 1),
#  ('praise', 1),
#  ('gets', 1),
#  ('dee', 1),
#  ('needs', 1),
#  ('been,', 1),
#  ('met,', 1),
#  ('forget', 1),
#  ('ya?', 1),
#  ('"yo,', 1),
#  ('pure', 1),
#  ('true."', 1),
#  ("'m", 1),
#  ('sister', 1),
#  ('diggin', 1),
#  ('imagine', 1),
#  ('weak,', 1),
#  ('took', 1),
#  ('kissed', 1),
#  ('gently', 1),
#  ('lips', 1),
#  ('poetry:', 1),
#  ('"i\'m', 1),
#  ('say."', 1),
#  ('(and', 1),
#  ('meant', 1),
#  ('solider', 1),
#  ('desperately', 1),
#  ('teacher', 1),
#  ('writers', 1),
#  ('*scat*', 1),
#  ('(you', 1),
#  ('(alright', 1),
#  ('(*joint', 1),
#  ('scat*)', 1),
#  ('gone', 1),
#  ("draggin'", 1),
#  ('must', 1),
#  ('hold', 1),
#  ('onto', 1),
#  ('miss', 1),
#  ('bus', 1),
#  ('hurry', 1),
#  ('stuff', 1),
#  ('coming,', 1),
#  ('niggas', 1),
#  ('true,', 1),
#  ('girl,', 1),
#  ('sometimes', 1),
#  ('hard', 1),
#  ('someone', 1),
#  ('hurts', 1),
#  ('deny', 1),
#  ('stop', 1),
#  ('crying', 1),
#  ("breathin',", 1),
#  ('garbage', 1),
#  ('grocery', 1),
#  ('talking', 1),
#  ('gucci', 1),
#  ('paper', 1),
#  ('nickel', 1),
#  ('backpack', 1),
#  ('back,', 1),
#  ('cheeba', 1),
#  ('babies?', 1),
#  ('plastic', 1),
#  ('mamas,', 1),
#  ('bookbag', 1),
#  ('ziploc', 1),
#  ('fendi', 1),
#  ('ladies?', 1),
#  ('shopping', 1),
#  ('run,', 1),
#  ('to?', 1),
#  ('from?', 1),
#  ('some', 1),
#  ('means', 1),
#  ('full', 1),
#  ('command', 1),
#  ('past,', 1),
#  ('sweet', 1),
#  ('sunshine', 1),
#  ('dig', 1),
#  ('pearls', 1),
#  ('teach', 1),
#  ('boys', 1),
#  ('girls', 1),
#  ('past', 1),
#  ('care,', 1),
#  ('swear', 1),
#  ('ahead', 1),
#  ('eats', 1),
#  ('help', 1),
#  ('lags', 1),
#  ("you've", 1),
#  ('something', 1),
#  ('control', 1),
#  ('do,', 1),
#  ('loving', 1),
#  ('la-di-da', 1),
#  ('dum-dee-da-da', 1),
#  ('dum-didi-da-di-da-di-da', 1),
#  ('dum-didi-da-di-dum-di', 1),
#  ('confused', 1),
#  ('trick', 1),
#  ('would,', 1),
#  ('dissed', 1),
#  ('makes', 1),
#  ('embarrassed', 1),
#  ('hide', 1),
#  ('meâ€”i', 1),
#  ('true', 1),
#  ('e.', 1),
#  ('heal,', 1),
#  ('while', 1),
#  ('while,', 1),
#  ("chil'", 1),
#  ('tooâ€”', 1),
#  ('feeling', 1),
#  ('has', 1),
#  ('sore', 1),
#  ('[part', 1),
#  ('iii]', 1),
#  ('sorry', 1),
#  ('first,', 1),
#  ('cool', 1),
#  ('loved', 1),
#  ('too,', 1),
#  ('wanted', 1),
#  ('desperate', 1),
#  ('plea', 1),
#  ('ye-ah,', 1),
#  ('nowhere,', 1),
#  ('on,', 1),
#  ('babe', 1),
#  ('strong', 1),
#  ('family', 1),
#  ('tough,', 1),
#  ('arms', 1),
#  ('friendship', 1),
#  ('our', 1),
#  ('growing', 1),
#  ('pains', 1)]
